# %% [markdown]
# **References**: https://github.com/blockchain-etl/ethereum-etl

# %% [markdown]
# # Problem Set 1 Checklist

# %% [markdown]
# **Please customize the following inputs to generate your own results for discussion**
#
#
# * Infura/Alchemy/QuickNode API endpoints: experiment with multiple node operators and see if you could get the same data
#
# * Data radius, start, and end blocks: pick a smaller radius for testing before you scale
#
# * Token address: Pick your choice of token in querying the token transfer part
#
# **Please post the sharing (Allow viewing or commenting only) URL for your Google Colab after you are done below.**
#
# Important: Change your private API token key to "API_KEY" before posting

# %% [markdown]
# ## Question 1 (5 points)
# Did you get the same data querying via different node operators? Please point to at least one specific observation to validate your answer.
#
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# The two tables are exactly the same. Comparing a block number from any node's database on the network will yield the same value.
#
# This is because every node on the network has the same (distributed) ledger of data (potentially at most 1 or 2 blocks behind). Therefore, no matter where blocks are queried from on the network they will yield the same result.

# %% [markdown]
# Alchemy API Results
#
# |index|number|hash|parent\_hash|nonce|sha3\_uncles|logs\_bloom|transactions\_root|state\_root|receipts\_root|miner|difficulty|total\_difficulty|size|extra\_data|gas\_limit|gas\_used|timestamp|transaction\_count|base\_fee\_per\_gas|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |0|15537493|0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486ce9034a86501c3d7651d|0x3dabb8d96bfc2dfeef5fad9be48afdb90a0d9011865d41b8c1f767f70eaa7fff|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xd022396d6bae98c72adec4fc96aa60bed379186af1fe932f5db5c64e9ce3d821|0x59b2d3cd234a375192dba0b038096f58902d042315e6d75501094252d6d0980f|0xd0488afff24558eea6ae67ec9f09edfc84a722d1fb6dfa06ca3c58bd62214d02|0x54cd0e6771b6487c721ec620c4de1240d3b07696|0|58750003716598352816469|212002|0x|30000000|29427315|1663225391|273|35073582545|
# |1|15537393|0x55b11b918355b1ef9c5db810302ebad0bf2544255b530cdce90674d5887bb286|0x2b3ea3cd4befcab070812443affb08bf17a91ce382c714a536ca3cacab82278b|0x62a3ee77461d4fc9|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xdd5eec02b019ff76e359b09bfa19395a2a0e97bc01e70d8d5491e640167c96a8|0x4919dafa6ac8becfbbd0c2808f6c9511a057c21e42839caff5dfb6d3ef514951|0xbaa842cfd552321a9c2450576126311e071680a1258032219c6490b663c1dab8|0x829bd824b016326a401d083b33d092293333a830|11055787484078698|58750003716598352816469|1636|0xe4b883e5bda9e7a59ee4bb99e9b1bc460021|30000000|29991429|1663224162|1|43391016710|
# |2|15537394|0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7a38d72842b762076a664|0x55b11b918355b1ef9c5db810302ebad0bf2544255b530cdce90674d5887bb286|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0x1ea1746468686159ce730c1cc49a886721244e5d1fa9a06d6d4196b6f013c82c|0x40c07091e16263270f3579385090fea02dd5f061ba6750228fcc082ff762fda7|0x928073fb98ce316265ea35d95ab7e2e1206cecd85242eb841dbbcc4f568fca4b|0xeee27662c2b8eba3cd936a23f039f3189633e4c8|0|58750003716598352816469|18559|0x|30000000|29983006|1663224179|80|48811794595|
# |3|15537395|0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e65c67c106513158a7db4|0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7a38d72842b762076a664|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0x5c56184fbce74e9c98d2a51aa2110963396047d84e8ce1ae1785337255cd11e0|0x2ca38a39c5517f658d107c19550334a9820a7393d14857f2c0e0458292668d64|0x1707e457973ce280debe93f5d478663d97ad192beea1f2fc65f391db80226e5e|0x0b3b161b8abeb6b04cb95c3e6047f80c120a0292|0|58750003716598352816469|36978|0x|30000000|29982083|1663224191|29|54906356355|
# |4|15537396|0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b2905cb23ad6c7a70ebaa40|0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e65c67c106513158a7db4|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xf103ec8f4895f63748a3f8d182af659736d1fc593d7117f22babf78e308ce36d|0xe6b8248ff047d9f34ecd82bcc1af2f45e08cd9157168988943b6da26f42dc105|0xf39845a5eabaa2848ff4c6bec8b1ede03ac5e6aa475eae66a5b3621a5b012038|0x388c818ca8b9251b393131c08a736a67ccb19297|0|58750003716598352816469|40259|0x|30000000|29980461|1663224203|170|61761452922|
#
# Quicknode API Results
#
#
# |index|number|hash|parent\_hash|nonce|sha3\_uncles|logs\_bloom|transactions\_root|state\_root|receipts\_root|miner|difficulty|total\_difficulty|size|extra\_data|gas\_limit|gas\_used|timestamp|transaction\_count|base\_fee\_per\_gas|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |0|15537493|0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486ce9034a86501c3d7651d|0x3dabb8d96bfc2dfeef5fad9be48afdb90a0d9011865d41b8c1f767f70eaa7fff|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xd022396d6bae98c72adec4fc96aa60bed379186af1fe932f5db5c64e9ce3d821|0x59b2d3cd234a375192dba0b038096f58902d042315e6d75501094252d6d0980f|0xd0488afff24558eea6ae67ec9f09edfc84a722d1fb6dfa06ca3c58bd62214d02|0x54cd0e6771b6487c721ec620c4de1240d3b07696|0|58750003716598352816469|212002|0x|30000000|29427315|1663225391|273|35073582545|
# |1|15537393|0x55b11b918355b1ef9c5db810302ebad0bf2544255b530cdce90674d5887bb286|0x2b3ea3cd4befcab070812443affb08bf17a91ce382c714a536ca3cacab82278b|0x62a3ee77461d4fc9|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xdd5eec02b019ff76e359b09bfa19395a2a0e97bc01e70d8d5491e640167c96a8|0x4919dafa6ac8becfbbd0c2808f6c9511a057c21e42839caff5dfb6d3ef514951|0xbaa842cfd552321a9c2450576126311e071680a1258032219c6490b663c1dab8|0x829bd824b016326a401d083b33d092293333a830|11055787484078698|58750003716598352816469|1636|0xe4b883e5bda9e7a59ee4bb99e9b1bc460021|30000000|29991429|1663224162|1|43391016710|
# |2|15537394|0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7a38d72842b762076a664|0x55b11b918355b1ef9c5db810302ebad0bf2544255b530cdce90674d5887bb286|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0x1ea1746468686159ce730c1cc49a886721244e5d1fa9a06d6d4196b6f013c82c|0x40c07091e16263270f3579385090fea02dd5f061ba6750228fcc082ff762fda7|0x928073fb98ce316265ea35d95ab7e2e1206cecd85242eb841dbbcc4f568fca4b|0xeee27662c2b8eba3cd936a23f039f3189633e4c8|0|58750003716598352816469|18559|0x|30000000|29983006|1663224179|80|48811794595|
# |3|15537395|0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e65c67c106513158a7db4|0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7a38d72842b762076a664|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0x5c56184fbce74e9c98d2a51aa2110963396047d84e8ce1ae1785337255cd11e0|0x2ca38a39c5517f658d107c19550334a9820a7393d14857f2c0e0458292668d64|0x1707e457973ce280debe93f5d478663d97ad192beea1f2fc65f391db80226e5e|0x0b3b161b8abeb6b04cb95c3e6047f80c120a0292|0|58750003716598352816469|36978|0x|30000000|29982083|1663224191|29|54906356355|
# |4|15537396|0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b2905cb23ad6c7a70ebaa40|0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e65c67c106513158a7db4|0x0000000000000000|0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347|...|0xf103ec8f4895f63748a3f8d182af659736d1fc593d7117f22babf78e308ce36d|0xe6b8248ff047d9f34ecd82bcc1af2f45e08cd9157168988943b6da26f42dc105|0xf39845a5eabaa2848ff4c6bec8b1ede03ac5e6aa475eae66a5b3621a5b012038|0x388c818ca8b9251b393131c08a736a67ccb19297|0|58750003716598352816469|40259|0x|30000000|29980461|1663224203|170|61761452922|

# %% [markdown]
# ## Question 2 (5 points)

# %% [markdown]
# Please introduce the ERC20 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *   what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# ERC20 Token: ApeCoin
#
# ApeCoin was first issued March 16, 2022. The token is part of the Bored Ape Yacht Club ecosystem. It is a 'utility coin', as holding the coin entitles users to voting rights. Coin owners may cast votes to make funding decisions, brand partnerships, and bylaws for the BYAC ecosystem. The current market cap is 2.22B, and it is currently trading at 6.11 USD (because it is an ERC20 token, it is a fungible token).
#
#
# I found this paper on utility coins and tokenization in general:
# Wang, G., &amp; Nixon, M. (2021). SOK. Proceedings of the 14th IEEE/ACM International Conference on Utility and Cloud Computing Companion. https://doi.org/10.1145/3492323.3495577
#
# Background: Tokenization is a potentially highly disruptive technology. However, the tokenization process is somewhat complicated, and a systematic review of the current ecosystem can be broadly beneficial.
#
# Research Question: The research question is, "What are the critical challenges and remaining research questions to advance research exploring the process of tokenization on the blockchain?"
#
# Application Scenario: The research is a meta-analysis, and so is meant to apply to all tokenization processes. ApeCoin is included under this umbrella, so the paper is useful in gaining a more complete understanding of the token.
#
# Methodology: This paper does not apply machine learning algorithms to the research question. Instead, it discusses the overall research space, by integrating research from across the field.
#
# Results and Intellectual Merits: The paper concludes that tokenization on the blockchain will be a greatly disruptive technology in the future and warrants further research. As such, the paper is intellectually useful as it provides an overview of the research space, and suggests some specific directions for future research/inquiry.

# %% [markdown]
# |index|token\_address|from\_address|to\_address|value|transaction\_hash|log\_index|block\_number|
# |---|---|---|---|---|---|---|---|
# |0|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0x0000e0ca771e21bd00057f54a68c30d400000000|17576853345269697620009|0x39f085d88d1bf78e94de740578c20c478a970750922249da1c1f2207460606c6|22|15537309|
# |1|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|3480815948226281452986|0x1bb3be5326b6b1644ce0871c9c82a4ce23ba502011eb7051a47cfeeb6e29477c|105|15537309|
# |2|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|0xe5859f4efc09027a9b718781dcb2c6910cac6e91|3480815948226281452986|0x1bb3be5326b6b1644ce0871c9c82a4ce23ba502011eb7051a47cfeeb6e29477c|109|15537309|
# |3|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|14293862435057414594374|0x264f6e130120a28874ffac7f44ce38565024f0c06745c15ad44247ad96c860ac|231|15537309|
# |4|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|0x7bbd8ca5e413bca521c2c80d8d1908616894cf21|14293862435057414594374|0x264f6e130120a28874ffac7f44ce38565024f0c06745c15ad44247ad96c860ac|236|15537309|

# %% [markdown]
# ### Question 3: (5 points)
#
# Please introduce the ERC721 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *  what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# In keeping with researching ApeCoin above, I chose Bored Ape Yacht Club tokens as my trading token to query data for. Bored Ape Yacht Club was released in April 2021 (once again, quite recently). In addition to intellectual property rights, there are some other functions that go along with owning the token. For example, owners of the token were distributed ApeCoin when it was first minted/released. Additionally, they are private online clubs and exclusive events offered to owners of BYAC NFT holders. BAYC NFTs have a very high floor price, around 100,000 USD.
#
# Journal Article:
# van Slooten, J. (2022). Predictive value of Tweet sentiment on the Bored Ape Yacht Club’s trading volume and floor price.
#
# Background: BAYC is one of the most successful NFT collections, with the highest market cap of all NFTs. Therefore, it is important to understand potential explanations for its success.
#
# Research Question: What is the effect of twitter data on the Bored Ape Yacht Club trading volume and floor price?
#
# Application Scenario: This paper is directly applicable to the BAYC trading ecosystem.
#
# Methodology: The paper queries Twitter data and uses sentiment extraction processes to evaluate if a given tweet is positive or negative. It then feeds this data into a machine learning algorithm to determine overall market sentiment, and predict current floor price and trading volume.
#
# Results: The resulting machine learning algorithm is able to generate predictions on trading valuation. However, as there is only 1 variable included in the model, it is relatively lowly correlated with actual price.
#
# Intellectual and Practical Merits: Predicting price valuation is important in all trading spaces, as accurately forecasting market sentiment is economically profitable.

# %% [markdown]
# |index|token\_address|from\_address|to\_address|value|transaction\_hash|log\_index|block\_number|
# |---|---|---|---|---|---|---|---|
# |0|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0x0000e0ca771e21bd00057f54a68c30d400000000|17576853345269697620009|0x39f085d88d1bf78e94de740578c20c478a970750922249da1c1f2207460606c6|22|15537309|
# |1|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|3480815948226281452986|0x1bb3be5326b6b1644ce0871c9c82a4ce23ba502011eb7051a47cfeeb6e29477c|105|15537309|
# |2|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|0xe5859f4efc09027a9b718781dcb2c6910cac6e91|3480815948226281452986|0x1bb3be5326b6b1644ce0871c9c82a4ce23ba502011eb7051a47cfeeb6e29477c|109|15537309|
# |3|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xd83d78108dd0d1dffff11ea3f99871671a52488b|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|14293862435057414594374|0x264f6e130120a28874ffac7f44ce38565024f0c06745c15ad44247ad96c860ac|231|15537309|
# |4|0x8e870d67f660d95d5be530380d0ec0bd388289e1|0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8|0x7bbd8ca5e413bca521c2c80d8d1908616894cf21|14293862435057414594374|0x264f6e130120a28874ffac7f44ce38565024f0c06745c15ad44247ad96c860ac|236|15537309|

# %% [markdown]
# # Part I: Install Required Dependancies

# %%
# install ethereum-etl and pandas
# !python -m pip install ethereum-etl pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 KB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.8/501.8 KB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 KB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 KB 4.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Part II: Mount Google Drive for Result Exports

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the current directory
# !pwd
# Out:
# /content

# %%
#@title path
#create a project folder and identify the path
path = "/content/drive/MyDrive/Binance" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content/drive/MyDrive/Binance
# Out:
# /content/drive/MyDrive/Binance

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content/drive/MyDrive/Binance

# %% [markdown]
# # Part III: Query Data and Export CSV

# %% [markdown]
# ## 0.Register Accounts on Remote Nodes Service and Get the URLs of the Nodes

# %% [markdown]
# ### Remote node option 1: Infura

# %% [markdown]
# !!! Important Notes: Please replace https://mainnet.infura.io/v3/API_KEY with your own endpoints for all the codes below

# %%
#@title Import using the Infura node
infura_end_points_URL = "https://mainnet.infura.io/v3/API_KEY" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 2: Alchemy

# %%
#@title import using Alchemy
alchemy_end_points_URL = "https://eth-mainnet.g.alchemy.com/v2/API_KEY" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 3: QuickNode

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://multi-prettiest-borough.discover.quiknode.pro/33fbada8b680afabb7dab2767ccf48a5b7073487/" #@param {type:"string"}

# %% [markdown]
# Data Range: We are going to query the block and transaction data for the ethereum blockchain before and after the merge (block number: 15537393 on September 15)
#
# Reference;
# https://www.investopedia.com/ethereum-completes-the-merge-6666337

# %%
#@title the merge
merge = 16500000 #@param {type:"number"}

# %%
#@title data radius
radius = 30 #@param {type:"number"}

# %%
### find the start and the end
start = merge-radius
end = merge+radius
print(start, end)
# Out:
# 15537293 15537493

# %% [markdown]
# ## 1. Query Block Data

# %% [markdown]
# ### using the infura endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537293  --end-block 15537493 --blocks-output blocks.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2023-01-29 12:44:21,266 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2023-01-29 12:44:21,313 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 943, in raise_for_status
# ...

# %%
# import libraries to print data frame
import pandas as pd

# %%
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
df_blocks = pd.read_csv('./blocks.csv')
display(df_blocks.head(10))
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-23-69d13ce03ea1> in <module>
# ----> 1 df_blocks = pd.read_csv('./blocks.csv')
#       2 display(df_blocks.head(10))
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ### query blockchain data using the alchemy endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537293 --end-block 15537493 --blocks-output blocks_alchemy.csv --provider-uri https://eth-mainnet.g.alchemy.com/v2/zsfMe_2M6CRKAYspOHAiBheOGxFuUPiD
# Out:
# 2023-01-29 12:49:41,245 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2023-01-29 12:49:41,444 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2023-01-29 12:49:41,457 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2023-01-29 12:49:41,457 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:00.212161.
# 2023-01-29 12:49:41,459 - CompositeItemExporter [INFO] - block items exported: 201
# 2023-01-29 12:49:41,459 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_alchemy = pd.read_csv('./blocks_alchemy.csv')
display(df_blocks_alchemy.head())
# Out:
#      number                                               hash  \
# 0  15537493  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...
# 1  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 2  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 3  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 4  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
#
#                                          parent_hash               nonce  \
# 0  0x3dabb8d96bfc2dfeef5fad9be48afdb90a0d9011865d...  0x0000000000000000
# 1  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...  0x62a3ee77461d4fc9
# 2  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...  0x0000000000000000
# 3  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...  0x0000000000000000
# 4  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...  0x0000000000000000
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# ...

# %% [markdown]
# ### query the data using the QuickNode endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537293  --end-block 15537493 --blocks-output blocks_QuickNode.csv --provider-uri https://multi-prettiest-borough.discover.quiknode.pro/33fbada8b680afabb7dab2767ccf48a5b7073487/

# %%
df_blocks_QuickNode = pd.read_csv('./blocks_QuickNode.csv')
display(df_blocks_QuickNode.head())
# Out:
#      number                                               hash  \
# 0  15537493  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...
# 1  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 2  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 3  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 4  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
#
#                                          parent_hash               nonce  \
# 0  0x3dabb8d96bfc2dfeef5fad9be48afdb90a0d9011865d...  0x0000000000000000
# 1  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...  0x62a3ee77461d4fc9
# 2  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...  0x0000000000000000
# 3  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...  0x0000000000000000
# 4  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...  0x0000000000000000
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# ...

# %% [markdown]
# ## 2. Query Transaction Data

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537293 --end-block 15537493 --transactions-output transactions.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2022-11-09 14:07:55,755 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2022-11-09 14:08:03,328 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2022-11-09 14:08:03,907 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2022-11-09 14:08:03,907 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:08.151989.
# 2022-11-09 14:08:03,908 - CompositeItemExporter [INFO] - block items exported: 0
# 2022-11-09 14:08:03,909 - CompositeItemExporter [INFO] - transaction items exported: 26358

# %%
df_transactions = pd.read_csv('./transactions.csv')
display(df_transactions.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-b6add20a1023> in <module>
# ----> 1 df_transactions = pd.read_csv('./transactions.csv')
#       2 display(df_transactions.head())
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ## 3. Query Token Data

# %% [markdown]
# ### 3.1 Query All Token Transfers

# %%
# !ethereumetl export_token_transfers --start-block 15537293 --end-block 15537493 --provider-uri https://multi-prettiest-borough.discover.quiknode.pro/33fbada8b680afabb7dab2767ccf48a5b7073487/ --output token_transfers.csv
# Out:
# 2023-01-29 13:19:57,898 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2023-01-29 13:20:16,103 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2023-01-29 13:20:20,073 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2023-01-29 13:20:20,073 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:22.175025.
# 2023-01-29 13:20:20,075 - CompositeItemExporter [INFO] - token_transfer items exported: 75100

# %%
df_token_transfers = pd.read_csv('./token_transfers.csv')
display(df_token_transfers.head())
# Out:
#                                 token_address  \
# 0  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 1  0xba100000625a3754423978a60c9317c58a424e3d
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3  0xf0f74a3fda30ea87c9cf19d1f16db8e0c011075b
# 4  0xc00e94cb662c3520282e6f5717214004a7f26888
#
#                                  from_address  \
# 0  0x0000000000000000000000000000000000000000
# 1  0xdc2c21f1b54ddaf39e944689a8f90cb844135cc9
# 2  0x4a137fd5e7a256ef08a7de531a17d0be0cc7b6b6
# 3  0x571b8569585483049ec3f0d7287b8e5b274332a0
# 4  0x2faf487a4414fe77e2327f0bf4ae2a264a776ad2
#
#                                    to_address                      value  \
# 0  0x7caa9f43822e288782e3e8797c8a16774c689b3d                       7370
# 1  0x4a137fd5e7a256ef08a7de531a17d0be0cc7b6b6      706670242473581543022
# 2  0xdc2c21f1b54ddaf39e944689a8f90cb844135cc9        2824319950172341760
# 3  0xf0c85e6d2d75e74ef0bb30f63c28ec3105fd6768  1822762000000000000000000
# ...

# %%
df = df_token_transfers[df_token_transfers.token_address=="0x4d224452801aced8b2f0aebe155379bb5d594381"]
df.head()
# Out:
#                                    token_address  \
# 225   0x4d224452801aced8b2f0aebe155379bb5d594381
# 1477  0x4d224452801aced8b2f0aebe155379bb5d594381
# 1480  0x4d224452801aced8b2f0aebe155379bb5d594381
# 1755  0x4d224452801aced8b2f0aebe155379bb5d594381
# 2025  0x4d224452801aced8b2f0aebe155379bb5d594381
#
#                                     from_address  \
# 225   0xb011eeaab8bf0c6de75510128da95498e4b7e67f
# 1477  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 1480  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 1755  0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf
# 2025  0x094739479e2685dc6f03aad39bdf29f56d033ff2
#
#                                       to_address                   value  \
# 225   0x76e2e5ca226df1c247c213105a8468427fcbc89f    39115659309151571381
# 1477  0xb011eeaab8bf0c6de75510128da95498e4b7e67f    38711383403372011000
# 1480  0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf  9256031277386095972851
# 1755  0x98c3d3183c4b8a650614ad179a1a98be0a8d6b8e  5437750000000190717272
# ...

# %% [markdown]
# ### 3.1 Query a specific ERC20 token transfers

# %% [markdown]
# *references*:
#
# * Commond Documentations: https://ethereum-etl.readthedocs.io/en/latest/commands/
# * Token Address: https://github.com/blockchain-etl/ethereum-etl-airflow/blob/master/dags/resources/stages/seed/data/token_amendments.csv
# * More detailed: https://github.com/blockchain-etl/ethereum-etl-airflow
# * Proof-of-Reserve: https://blog.chain.link/stablecoins-and-proof-of-reserve/

# %%
#@title Token Name
Token_Name = "Ape Coin" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "APE" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x4d224452801aced8b2f0aebe155379bb5d594381" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537293 --end-block 15537493 --provider-uri https://multi-prettiest-borough.discover.quiknode.pro/33fbada8b680afabb7dab2767ccf48a5b7073487/ --output token_transfers_USDP.csv --tokens 0x8E870D67F660D95d5be530380D0eC0bd388289E1
# Out:
# 2023-01-29 13:22:00,472 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2023-01-29 13:22:00,586 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2023-01-29 13:22:00,597 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2023-01-29 13:22:00,597 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:00.125066.
# 2023-01-29 13:22:00,598 - CompositeItemExporter [INFO] - token_transfer items exported: 17

# %%
df_token_transfers_USDP = pd.read_csv('./token_transfers_USDP.csv')
display(df_token_transfers_USDP.head())
# Out:
#                                 token_address  \
# 0  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 1  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 2  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 3  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 4  0x8e870d67f660d95d5be530380d0ec0bd388289e1
#
#                                  from_address  \
# 0  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 1  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 2  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8
# 3  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 4  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8
#
#                                    to_address                    value  \
# 0  0x0000e0ca771e21bd00057f54a68c30d400000000  17576853345269697620009
# 1  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8   3480815948226281452986
# 2  0xe5859f4efc09027a9b718781dcb2c6910cac6e91   3480815948226281452986
# 3  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8  14293862435057414594374
# ...

# %% [markdown]
# ### 3.1 Query a specific ERC721 token transfers

# %%
#@title Token Name
Token_Name = "Ape Tokens" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "$APE" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d " #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537293 --end-block 15537493 --provider-uri https://multi-prettiest-borough.discover.quiknode.pro/33fbada8b680afabb7dab2767ccf48a5b7073487/ --output token_transfers_.csv --tokens 0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d
# Out:
# 2023-01-29 14:04:14,597 - ProgressLogger [INFO] - Started work. Items to process: 201.
# Traceback (most recent call last):
#   File "/usr/local/bin/ethereumetl", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/cli/export_token_transfers.py", line 58, in export_token_transfers
# ...

# %%
df_token_transfers_USDP = pd.read_csv('./token_transfers_BAYC.csv')
display(df_token_transfers_USDP.head())
# Out:
#                                 token_address  \
# 0  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 1  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 2  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 3  0x8e870d67f660d95d5be530380d0ec0bd388289e1
# 4  0x8e870d67f660d95d5be530380d0ec0bd388289e1
#
#                                  from_address  \
# 0  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 1  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 2  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8
# 3  0xd83d78108dd0d1dffff11ea3f99871671a52488b
# 4  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8
#
#                                    to_address                    value  \
# 0  0x0000e0ca771e21bd00057f54a68c30d400000000  17576853345269697620009
# 1  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8   3480815948226281452986
# 2  0xe5859f4efc09027a9b718781dcb2c6910cac6e91   3480815948226281452986
# 3  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8  14293862435057414594374
# ...
